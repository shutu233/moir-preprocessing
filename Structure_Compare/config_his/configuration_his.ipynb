# %%
import os
os.chdir('/global/homes/l/ltshu/Simulation/struc_compare/config_his')

# %%
import numpy as np
import matplotlib.pyplot as plt

from ase.io import read, write

# %%
import sys
sys.path.append('/global/homes/l/ltshu/Simulation/Rattle')
import atoms_minimize_bei

# %%
import config_his

# %% [markdown]
# # 6atoms issue

# %%
at1 = read("/global/homes/l/ltshu/Simulation/struc_compare/build_struc/MoS2-Bilayer_AA_6atoms.xyz", index=0, format='extxyz')
at2 = read("/global/homes/l/ltshu/Simulation/Rattle/6atoms/struc_shifted_rattle_AA6atoms_N3/N3_local_0.xyz", index=-1, format='extxyz')
layer1 = read('/global/homes/l/ltshu/Simulation/struc_compare/build_struc/MoS2_monolayer.xyz')
layer2 = read('/global/homes/l/ltshu/Simulation/struc_compare/build_struc/MoS2_monolayer.xyz')

# %%
import importlib
importlib.reload(config_his)
# Out:
# <module 'config_his' from '/global/u2/l/ltshu/Simulation/struc_compare/config_his/config_his.py'>

# %%
config_his.Configure_Histogram(at1, at2, layer1, layer2)
# Out:
# Calculating Wasserstein distance...
# Wasserstein distance between original and relaxed structures: 0.0

# %%
at1 = read("/global/homes/l/ltshu/Simulation/Rattle/6atoms/struc_shifted_rattle_AA6atoms_N3/N3_local_0.xyz", index=0, format='extxyz')
at2 = read("/global/homes/l/ltshu/Simulation/Rattle/6atoms/struc_shifted_rattle_AA6atoms_N3/N3_local_1.xyz", index=-1, format='extxyz')
layer1 = read('/global/homes/l/ltshu/Simulation/struc_compare/build_struc/MoS2_monolayer.xyz')
layer2 = read('/global/homes/l/ltshu/Simulation/struc_compare/build_struc/MoS2_monolayer.xyz')

# %%
config_his.Configure_Histogram(at1, at2, layer1, layer2)
# Out:
# Calculating Wasserstein distance...
# Wasserstein distance between original and relaxed structures: 1.580105

# %%
at1 = read("/global/homes/l/ltshu/Simulation/Rattle/6atoms/struc_shifted_rattle_AA6atoms_N3/N3_local_0.xyz", index=0, format='extxyz')
at2 = read("/global/homes/l/ltshu/Simulation/Rattle/6atoms/struc_shifted_rattle_AA6atoms_N3/N3_local_9.xyz", index=-1, format='extxyz')
layer1 = read('/global/homes/l/ltshu/Simulation/struc_compare/build_struc/MoS2_monolayer.xyz')
layer2 = read('/global/homes/l/ltshu/Simulation/struc_compare/build_struc/MoS2_monolayer.xyz')

# %%
config_his.Configure_Histogram(at1, at2, layer1, layer2)
# Out:
# Calculating Wasserstein distance...
# Wasserstein distance between original and relaxed structures: 1.8245480941957473

# %% [markdown]
# twisted structures

# %% [markdown]
# 弛豫前和弛豫后

# %%
at1 = read('/global/homes/l/ltshu/Simulation/Structures/01-4.00_deg-540_atoms.xyz')
at2 = read('/global/homes/l/ltshu/Simulation/Rattle/540atoms_4deg/N10/N10_local_0.xyz')
layer1 = read('/global/homes/l/ltshu/Simulation/moiretest/MoS2.xyz')
layer2 = read('/global/homes/l/ltshu/Simulation/moiretest/MoSe2.xyz')

# %%
config_his.Configure_Histogram(at1, at2, layer1, layer2)
# Out:
# Calculating Wasserstein distance...
# Wasserstein distance between original and relaxed structures: 0.1208468544511224

# %% [markdown]
# 两个弛豫后

# %%
at1 = read('/global/homes/l/ltshu/Simulation/Rattle/540atoms_4deg/N10/N10_local_0.xyz')
at2 = read('/global/homes/l/ltshu/Simulation/Rattle/540atoms_4deg/N10/N10_local_20.xyz')
layer1 = read('/global/homes/l/ltshu/Simulation/moiretest/MoS2.xyz')
layer2 = read('/global/homes/l/ltshu/Simulation/moiretest/MoSe2.xyz')

# %%
config_his.Configure_Histogram(at1, at2, layer1, layer2)
# Out:
# Calculating Wasserstein distance...
# Wasserstein distance between original and relaxed structures: 0.02839401283194975

# %% [markdown]
# 两个弛豫前 (平移)

# %%
at1 = read('/global/homes/l/ltshu/Simulation/Rattle/shift_traj.xyz', index=0)
at2 = read('/global/homes/l/ltshu/Simulation/Rattle/shift_traj.xyz', index=5)
layer1 = read('/global/homes/l/ltshu/Simulation/moiretest/MoS2.xyz')
layer2 = read('/global/homes/l/ltshu/Simulation/moiretest/MoSe2.xyz')

# %%
config_his.Configure_Histogram(at1, at2, layer1, layer2)
# Out:
# Calculating Wasserstein distance...
# Wasserstein distance between original and relaxed structures: 0.047825839189953846

# %% [markdown]
# 1D structure 25-26 atoms

# %%
at1 = read('/global/homes/l/ltshu/Simulation/struc_compare/config_his/1D_25cells_0deg.xyz')
at2 = read('/global/homes/l/ltshu/Simulation/Rattle/trajectories/MoS2_25_0.traj.xyz', index=-1, format='extxyz')
layer1 = read('/global/homes/l/ltshu/Simulation/struc_compare/build_struc/MoS2_monolayer.xyz')
layer2 = read('/global/homes/l/ltshu/Simulation/Structures/2526MoS2_layer_2.xyz')

# %%
config_his.Configure_Histogram(at1, at2, layer1, layer2)
# Out:
# Calculating Wasserstein distance...
# Wasserstein distance between original and relaxed structures: 0.9405411607172901

# %%
at1 = read('/global/homes/l/ltshu/Simulation/Rattle/2526MoS21D/N10/N10_local_1.xyz', format='extxyz')
at2 = read('/global/homes/l/ltshu/Simulation/Rattle/2526MoS21D/N10/N10_local_0.xyz', index=-1, format='extxyz')
layer1 = read('/global/homes/l/ltshu/Simulation/struc_compare/build_struc/MoS2_monolayer.xyz')
layer2 = read('/global/homes/l/ltshu/Simulation/Structures/2526MoS2_layer_2.xyz')

# %%
config_his.Configure_Histogram(at1, at2, layer1, layer2)
# Out:
# Calculating Wasserstein distance...
# Wasserstein distance between original and relaxed structures: 0.05706208676567245
